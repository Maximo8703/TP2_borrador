# %% [markdown]
# <a href="https://colab.research.google.com/github/Maximo8703/TP2_borrador/blob/main/TP2_parte2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
#importo las bases de datos, t1_24 y t1_25

df1 = pd.read_excel("usu_individual_T125.xlsx")

df2 = pd.read_excel("usu_individual_T124.xlsx")

# %%
#selecciono columnas a analizar

t1_25b = df1[["SECTOR", "ESTADO", "CAT_OCUP", "P21", "P47T", "NIVEL_ED", "CH04", "CH06", "CH07", "CH08"]]
t1_24b = df2[["SECTOR", "ESTADO", "CAT_OCUP", "P21", "P47T", "NIVEL_ED", "CH04", "CH06", "CH07", "CH08"]]

t1_25b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45425 entries, 0 to 45424
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SECTOR    20076 non-null  float64
#  1   ESTADO    45425 non-null  int64
#  2   CAT_OCUP  45425 non-null  int64
#  3   P21       45425 non-null  int64
#  4   P47T      45350 non-null  float64
#  5   NIVEL_ED  45425 non-null  int64
#  6   CH04      45425 non-null  int64
#  7   CH06      45425 non-null  int64
#  8   CH07      45425 non-null  int64
#  9   CH08      45424 non-null  float64
# dtypes: float64(3), int64(7)
# memory usage: 3.5 MB

# %%
t1_25b.to_excel("t1_25_eph.xlsx", index=False)

# %%
t1_24b.to_excel("t1_24_eph.xlsx", index=False)

# %%
print("Valores únicos y sus recuentos en la columna 'SECTOR' de t1_25:")
display(t1_25b['SECTOR'].value_counts(dropna=False))
# Out:
# Valores únicos y sus recuentos en la columna 'SECTOR' de t1_25:
# SECTOR
# NaN    25349
# 1.0    13387
# 2.0     4504
# 3.0     1332
# 9.0      853
# Name: count, dtype: int64

# %%
t1_25b.head()
#Las variables de Sector son Nan automaticamente
# Out:
#    SECTOR  ESTADO  CAT_OCUP     P21      P47T  NIVEL_ED  CH04  CH06  CH07  \
# 0     1.0       1         3  200000  628000.0         4     2    25     1
# 1     NaN       4         0       0       0.0         1     2     7     5
# 2     NaN       4         0       0       0.0         7     1     4     5
# 3     NaN       4         0       0       0.0         7     1    -1     5
# 4     2.0       1         2  400000  690000.0         5     2    29     5
#
#    CH08
# 0   4.0
# 1   4.0
# 2   4.0
# 3   4.0
# 4   4.0

# %%
t1_24b.head()
# Out:
#    SECTOR  ESTADO  CAT_OCUP     P21      P47T  NIVEL_ED  CH04  CH06  CH07  \
# 0     NaN       3         0       0      -9.0         2     2    86     4
# 1     2.0       1         2  150000  280000.0         2     1    68     3
# 2     NaN       2         2       0       0.0         4     1    20     5
# 3     NaN       3         0       0  400000.0         6     2    75     3
# 4     2.0       1         2  250000  250000.0         4     2    41     1
#
#    CH08
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
#Vamos con la matriz de correlación

import seaborn as sns

# %%
#Generación el array

#Para el Primer Trimestre 2024

sns.heatmap(t1_24b.corr(), vmin=-1, vmax=+1, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
#Para el Primer Trimestre 2025

sns.heatmap(t1_25b.corr(), vmin=-1, vmax=+1, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# Parte II
# 6

# %%
#Primer Trimestre 2024

t1_24b
# Out:
#        SECTOR  ESTADO  CAT_OCUP     P21      P47T  NIVEL_ED  CH04  CH06  CH07  \
# 0         NaN       3         0       0      -9.0         2     2    86     4
# 1         2.0       1         2  150000  280000.0         2     1    68     3
# 2         NaN       2         2       0       0.0         4     1    20     5
# 3         NaN       3         0       0  400000.0         6     2    75     3
# 4         2.0       1         2  250000  250000.0         4     2    41     1
# ...       ...     ...       ...     ...       ...       ...   ...   ...   ...
# 46045     NaN       3         0       0       0.0         4     1    19     5
# 46046     3.0       1         3   40000  130000.0         2     2    54     2
# 46047     2.0       1         2      -9      -9.0         2     2    56     2
# 46048     1.0       1         3  300000  450000.0         4     1    39     2
# 46049     1.0       1         2      -9      -9.0         6     2    40     1
#
#        CH08
# 0         1
# ...

# %%
#Estadística Descriptiva

#número de observaciones
#promedio,
#desvío estandar,
#min,
#p1, p25, p50, p75, p99
#max.

t1_24b.describe(percentiles=[0.25, 0.5, 0.75, 0.99]).round(2)
# Out:
#          SECTOR    ESTADO  CAT_OCUP          P21         P47T  NIVEL_ED  \
# count  20325.00  46050.00  46050.00     46050.00     45969.00  46050.00
# mean       1.66      2.20      1.26    109536.03    173416.37      3.75
# std        1.60      1.14      1.40    236313.80    336658.23      1.75
# min        1.00      0.00      0.00        -9.00        -9.00      1.00
# 25%        1.00      1.00      0.00         0.00         0.00      3.00
# 50%        1.00      3.00      0.00         0.00     68000.00      4.00
# 75%        2.00      3.00      3.00    154000.00    250000.00      5.00
# 99%        9.00      4.00      3.00    900000.00   1200000.00      7.00
# max        9.00      4.00      4.00  10000000.00  32600000.00      7.00
#
#            CH04      CH06      CH07      CH08
# count  46050.00  46050.00  46050.00  46050.00
# mean       1.52     36.29      3.52      2.15
# std        0.50     22.21      1.66      2.37
# min        1.00     -1.00      1.00      1.00
# ...

# %%
t1_25b.describe(percentiles=[0.25, 0.5, 0.75, 0.99]).round(2)
# Out:
#          SECTOR    ESTADO  CAT_OCUP          P21         P47T  NIVEL_ED  \
# count  20076.00  45425.00  45425.00     45425.00     45350.00  45425.00
# mean       1.70      2.19      1.26    254528.63    409221.23      3.76
# std        1.65      1.13      1.40    549868.14    688178.32      1.73
# min        1.00      0.00      0.00        -9.00        -9.00      1.00
# 25%        1.00      1.00      0.00         0.00         0.00      3.00
# 50%        1.00      3.00      0.00         0.00    128686.00      4.00
# 75%        2.00      3.00      3.00    380000.00    600000.00      5.00
# 99%        9.00      4.00      3.00   2000000.00   2807650.00      7.00
# max        9.00      4.00      9.00  25000000.00  25000000.00      7.00
#
#            CH04      CH06      CH07      CH08
# count  45425.00  45425.00  45425.00  45424.00
# mean       1.52     36.79      3.52      2.14
# std        0.50     22.14      1.65      2.02
# min        1.00     -1.00      1.00      1.00
# ...
